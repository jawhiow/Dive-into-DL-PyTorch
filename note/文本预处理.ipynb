# %%
# colab预处理
# !mkdir /content/input/timemachine7163

# %%
# 链接到colab
# !cp '/content/drive/My Drive/Colab Notebooks/库练习/动手学习深度学习/timemachine.txt' /content/input/timemachine7163/

# %% [markdown]
# # 读入文本
# 我们用一部英文小说，即H. G. Well的Time Machine，作为示例，展示文本预处理的具体过程。

# %%
import collections
import re

def read_time_machine():
    with open('/content/input/timemachine7163/timemachine.txt', 'r') as f:
        lines = [re.sub('[^a-z]+', ' ', line.strip().lower()) for line in f]
    return lines


lines = read_time_machine()
print('# sentences %d' % len(lines))
# Out:
# # sentences 3231
